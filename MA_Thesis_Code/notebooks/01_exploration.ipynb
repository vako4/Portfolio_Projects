# %% [markdown]
# # 01 — Data exploration
#
# Scratch notebook for inspecting raw data, checking constituent coverage, and verifying the price download before the pipeline is run end-to-end.

# %%
import sys
sys.path.insert(0, '..')

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from src import config

sns.set_theme(style='whitegrid')
print('DATA_START:', config.DATA_START)
print('EVAL_START:', config.EVAL_START)
print('EVAL_END  :', config.EVAL_END)

# %% [markdown]
# ## Price download smoke test

# %%
# TODO: call data_pull.download_prices once implemented

# %% [markdown]
# ## Constituent coverage

# %%
# TODO: inspect membership matrix once constituents.py is implemented
